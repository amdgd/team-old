# %%
PUT /jal
{
  "mappings": {
    "user": {
        "city" :{
            "type" : "keyword"
        }
        _at 
        _i integar
        _f float
            string
        
    }, 
  }
}

# %%
PUT /company
{
  "mappings": {
    "branch": {},
    "employee": {
      "_parent": {
        "type": "branch" 
      }
    }
  }
}


Index = Project ID
Mappings 
    Parent - User
    Child - Events

All tags will be added to event mapping as timestamp and variable


Event 
    _id = Autogenerated
    variables
        - eventID
        - timestamp
        - eventname/event_type
        - el

# %% [markdown]
# - Should we have seperate index for each projects?
# - If a client becomes inactive? It's data is still there.
