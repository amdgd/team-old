# %% [markdown]
# # Seaborn
# Matplotlib is not designed for use with Pandas dataframes. In order to visualize data from a Pandas dataframe, you must extract each series and often concatenate these series’ together into the right format.
#
# Seaborn provides an API on top of matplotlib which uses sane plot & color defaults, uses simple functions for common statistical plot types, and which integrates with the functionality provided by Pandas dataframes

# %% [markdown]
# ## Import packages

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt

# Importing Pandas
import pandas as pd

#Import Warnings
import warnings

# Seaborn for plotting and styling
import seaborn as sns

#Fixed size for all plots
plt.rcParams['figure.figsize']=12,8

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Color Palettes and Style

# %%
# Default settings
# sns.set()
sns.set(style="darkgrid")

# %%
car_dataset_url ='https://raw.githubusercontent.com/ankitind/sample_datasets/master/car_ad.csv'
car_ads = pd.read_csv(car_dataset_url)

# %%
len(car_ads)
# Out:
# 9576

# %%
car_ads.columns = ['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
       'year', 'model', 'drive']

# %%
car_ads.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
#print(car_ads.head())
c1 = car_ads[car_ads.year > 1999]
c1.dropna

b1 = c1[['body', 'year', 'price']]
b2 = b1.groupby([ 'year', 'body']).median()
b2.dropna()
b2 = b2.reset_index()
b = b2.pivot(index="year", columns="body", values="price")



b11 = c1[['engType', 'year', 'price']]
b21 = b11.groupby([ 'year', 'engType']).median()
b21.dropna()
b21 = b21.reset_index()
b1 = b21.pivot(index="year", columns="engType", values="price")


fig, ax = plt.subplots(1,2, figsize=(15,6))
f1 = sns.heatmap(b, ax=ax[0])
f2 = sns.heatmap(b1, ax=ax[1])

sns.plt.suptitle('HEATMAP wrt to year of manufacture')

plt.show()

# %%
car_ads.car = car_ads.car.astype('category')
car_ads.body = car_ads.body.astype('category')
car_ads.engType = car_ads.engType.astype('category')
car_ads.model = car_ads.model.astype('category')
car_ads.drive = car_ads.drive.astype('category')
car_ads.registration = car_ads.registration.astype('category')

# %%
car_ads['car'].dtype
# Out:
# category

# %%
print(car_ads['car'].value_counts().head(6))

def show_unique_values_categories(df):
    for col in df:
       if (str(car_ads[col].dtype) == "category"):
            print("\n_____________________________________________________________________\n")
            print("Column: " + col )
            print("Unique Values: " + str(car_ads[col].value_counts().count()) + "\n")
            print(car_ads[col].cat.categories.values)
        
        
show_unique_values_categories(car_ads)
# Out:
# Volkswagen       936
# Mercedes-Benz    921
# BMW              694
# Toyota           541
# VAZ              489
# Renault          469
# Name: car, dtype: int64
#
# _____________________________________________________________________
#
# Column: car
# Unique Values: 87
#
# ['Acura' 'Alfa Romeo' 'Aro' 'Aston Martin' 'Audi' 'BMW' 'BYD' 'Barkas'
#  'Bentley' 'Bogdan' 'Buick' 'Cadillac' 'Changan' 'Chery' 'Chevrolet'
#  'Chrysler' 'Citroen' 'Dacia' 'Dadi' 'Daewoo' 'Daihatsu' 'Dodge' 'FAW'
#  'Ferrari' 'Fiat' 'Fisker' 'Ford' 'GAZ' 'GMC' 'Geely' 'Great Wall' 'Groz'
#  'Hafei' 'Honda' 'Huanghai' 'Hummer' 'Hyundai' 'Infiniti' 'Isuzu' 'JAC'
#  'Jaguar' 'Jeep' 'Kia' 'Lamborghini' 'Lancia' 'Land Rover' 'Lexus' 'Lifan'
#  'Lincoln' 'MG' 'MINI' 'Maserati' 'Mazda' 'Mercedes-Benz' 'Mercury'
#  'Mitsubishi' 'Moskvich-AZLK' 'Moskvich-Izh' 'Nissan' 'Opel' 'Other-Retro'
#  'Peugeot' 'Porsche' 'Renault' 'Rolls-Royce' 'Rover' 'SMA' 'Saab' 'Samand'
#  'Samsung' 'Seat' 'Skoda' 'Smart' 'SsangYong' 'Subaru' 'Suzuki' 'TATA'
#  'Tesla' 'Toyota' 'UAZ' 'VAZ' 'Volkswagen' 'Volvo' 'Wartburg' 'ZAZ' 'ZX'
#  '�UAZ']
#
# _____________________________________________________________________
#
# Column: body
# Unique Values: 6
#
# ['crossover' 'hatch' 'other' 'sedan' 'vagon' 'van']
#
# _____________________________________________________________________
#
# Column: engType
# Unique Values: 4
#
# ['Diesel' 'Gas' 'Other' 'Petrol']
#
# _____________________________________________________________________
#
# Column: registration
# Unique Values: 2
#
# ['no' 'yes']
#
# _____________________________________________________________________
#
# Column: model
# Unique Values: 863
#
# ['1 Series' '1.3' '10' '100' '106' '107' '11' '1102 ������' '1103 �������'
#  '110557' '1117' '1118' '1119' '116' '118' '120' '125' '1301' '1302' '147'
#  '156' '159' '19' '190' '2' '200' '2008' '205' '206' '207' '208' '21' '210'
#  '2101' '2102' '2103' '2104' '2105' '2106' '2107' '2108' '2109'
#  '2109 (�������)' '21093' '21099' '2110' '2111' '2112' '2113' '2114' '2115'
#  '2117' '2121' '2123' '2140' '2141' '2170' '2171' '2172' '2190 ������'
#  '220' '230' '24' '240' '2410' '25' '250' '2705 GAZ���' '2715' '2717'
#  '2752 ������' '3' '300' '300 C' '300 M' '3008' '301' '306' '307' '308'
#  '31029' '3110' '31105' '3151' '31512' '31514' '316' '3163' '318' '320'
#  '3221 GAZ���' '32213' '323' '324' '325' '328' '33' '330' '3302 GAZ���'
#  '3303' '335' '340' '350' '350Z' '3741' '3962' '4 Series Gran Coupe' '401'
#  '403' '405' '406' '407' '412' '428' '452 ����.' '458 Italia' '469' '469�'
#  '4Runner' '5' '5 Series' '5 Series GT' '500' '500 L' '5008' '508' '520'
#  '523' '524' '525' '528' '530' '535' '540' '545' '550' '6' '6 MPS'
#  '6 Series Gran Coupe' '605' '607' '626' '630' '640' '645' '650' '69' '728'
#  '730' '735' '740' '745' '75' '750' '760' '80' '850' '9' '9-May' '90' '911'
#  '965' '968' '969 ������' '969�' 'A 140' 'A 150' 'A 160' 'A 170' 'A 180'
#  'A1' 'A3' 'A4' 'A4 Allroad' 'A5' 'A6' 'A6 Allroad' 'A7' 'A8' 'ASX'
#  'Acadia' 'Accent' 'Accord' 'Actyon' 'Actyon Sports' 'Agila' 'Almera'
#  'Alpina' 'Altea' 'Altea XL' 'Altima' 'Amarok' 'Ampera' 'Amulet' 'Antara'
#  'Armada' 'Ascona' 'Astra F' 'Astra G' 'Astra H' 'Astra J' 'Astro ����.'
#  'Auris' 'Aurora' 'Avalon' 'Avenger' 'Avensis' 'Aveo' 'Aygo' 'B 170'
#  'B 180' 'B 200' 'B-Class Electric Drive' 'B-Max' 'B1000' 'BDD' 'Beat'
#  'Beetle' 'Bentayga' 'Berlingo ����.' 'Besta' 'Bipper ����.' 'Bluebird'
#  'Bora' 'Boxer ����.' 'Bravo' 'C-Class' 'C-Elysee' 'C-Max' 'C1' 'C3'
#  'C3 Picasso' 'C30' 'C4' 'C4 Picasso' 'C5' 'CK' 'CK-2' 'CK1' 'CL 180'
#  'CL 500' 'CL 55 AMG' 'CL 550' 'CL 63 AMG' 'CLA 200' 'CLA 220' 'CLA-Class'
#  'CLC 180' 'CLC 200' 'CLK 200' 'CLK 220' 'CLK 230' 'CLK 240' 'CLK 280'
#  'CLK 320' 'CLK 430' 'CLS 350' 'CLS 400' 'CLS 500' 'CLS 63 AMG' 'CR-V' 'CT'
#  'CX-5' 'CX-7' 'CX-9' 'Cabrio' 'Caddy' 'Caddy ����.' 'Caliber' 'Calibra'
#  'California' 'Camaro' 'Camry' 'Captiva' 'Captur' 'Caravelle' 'Carens'
#  'Carina' 'Carisma' 'Carnival' 'Cayenne' 'Cayman' 'Ceed' 'Cefiro' 'Celica'
#  'Century' 'Cerato' 'Challenger' 'Cherokee' 'Cinquecento' 'City' 'Civic'
#  'Clarus' 'Clio' 'Cobalt' 'Colt' 'Combo ����.' 'Compass' 'Continental'
#  'Cooper' 'Cooper S' 'Cordoba' 'Corolla' 'Corolla Verso' 'Corsa' 'Corvette'
#  'Countryman' 'Coupe' 'Courier' 'Cross Touran' 'CrossEastar' 'Crossfire'
#  'Crosstour' 'Cruze' 'Cuore' 'D-Max' 'DB9' 'DS3' 'DS4' 'DS5' 'Daimler'
#  'Defender' 'Discovery' 'Discovery Sport' 'Doblo Panorama' 'Doblo ����.'
#  'Dokker ����.' 'Ducato ����.' 'Durango' 'Duster' 'E-Class' 'EL' 'ES 200'
#  'ES 300' 'ES 330' 'ES 350' 'EX 35' 'EX 37' 'Eastar' 'Eclipse' 'Edge'
#  'Elantra' 'Elara' 'Elgrand' 'Emgrand 7 (EC7)' 'Emgrand 8' 'Emgrand X7'
#  'Eos' 'Epica' 'Escalade' 'Escort' 'Escort van' 'Espace' 'Espero' 'Evanda'
#  'Expert ����.' 'Explorer' 'Express ����.' 'F-150' 'F-350' 'F3' 'F3R'
#  'FJ Cruiser' 'FX 30' 'FX 35' 'FX 37' 'FX 45' 'Fabia' 'Felicia' 'Fiesta'
#  'Fiorino ����.' 'Fluence' 'Flying Spur' 'Focus' 'Focus Electric'
#  'Forester' 'Forfour' 'Fortuner' 'Fortwo' 'Forza' 'Freelander' 'Frontera'
#  'Fusion' 'G 320' 'G 350' 'G 500' 'G 55 AMG' 'G 63 AMG' 'G25' 'G35' 'G37'
#  'GC6' 'GL 320' 'GL 350' 'GL 420' 'GL 450' 'GL 500' 'GL 550' 'GLC-Class'
#  'GLE-Class' 'GLK 220' 'GLK 300' 'GLS 350' 'GLS 400' 'GLS 500' 'GLS 63'
#  'GS 250' 'GS 300' 'GS 350' 'GT-R' 'GX' 'Galant' 'Galaxy' 'Gallardo'
#  'Galloper' 'Genesis' 'Gentra' 'Getz' 'Giulietta' 'Gloria' 'Golf GTI'
#  'Golf II' 'Golf III' 'Golf IV' 'Golf Plus' 'Golf V' 'Golf VI' 'Golf VII'
#  'Golf Variant' 'Gran Move' 'GranTurismo' 'Granada' 'Grand C4 Picasso'
#  'Grand Cherokee' 'Grand Marquis' 'Grand Scenic' 'Grand Vitara'
#  'Grand Voyager' 'Grande Punto' 'Grandeur' 'Grandis' 'H 100 ����.'
#  'H 200 ����.' 'H1 ����.' 'H2' 'H3' 'HR-V' 'Haval' 'Hiace ����.'
#  'Highlander' 'Hilux' 'Hover' 'I3' 'IQ' 'IS 200' 'IS 250' 'IS 300' 'IX35'
#  'Ibiza' 'Ideal' 'Ignis' 'Impreza' 'Impreza WRX STI' 'Insight' 'Insignia'
#  'Intrepid' 'J2' 'Jaggi' 'Jazz' 'Jetta' 'Jimny' 'Juke' 'Juke Nismo'
#  'Jumper ����.' 'Jumpy ����.' 'KA' 'Kadett' 'Kangoo ����.' 'Karma' 'Kimo'
#  'Kizashi' 'Koleos' 'Korando' 'Koup' 'Kubistar' 'Kuga' 'Kyron' 'L 200'
#  'L 400 ����.' 'LHS' 'LS 400' 'LS 430' 'LS 460' 'LT ����.' 'LX 450'
#  'LX 470' 'LX 570' 'Lacetti' 'Laguna' 'Lancer' 'Lancer Evolution'
#  'Lancer X' 'Lancer X Sportback' 'Land Cruiser 100' 'Land Cruiser 105'
#  'Land Cruiser 200' 'Land Cruiser 76' 'Land Cruiser 80'
#  'Land Cruiser Prado' 'LandMark' 'Lanos' 'Latitude' 'Leaf' 'Legacy'
#  'Leganza' 'Legend' 'Leon' 'Linea' 'Lite Ace' 'Logan' 'Lumina' 'Lupo' 'M11'
#  'M35' 'M37' 'M5' 'M6' 'MB ����.' 'MDX' 'MK' 'MK Cross' 'MK-2' 'MKX'
#  'ML 250' 'ML 270' 'ML 280' 'ML 320' 'ML 350' 'ML 400' 'ML 430' 'ML 500'
#  'ML 550' 'ML 63 AMG' 'MPV' 'Macan' 'Magentis' 'Malibu' 'Manta' 'Maple C81'
#  'Mark II' 'Master ����.' 'Matiz' 'Matrix' 'Maxima' 'Megane' 'Micra'
#  'Model S' 'Model X' 'Modus' 'Mohave' 'Mondeo' 'Mulsanne' 'Multivan'
#  'Murano' 'Mustang' 'Mustang GT' 'NV' 'NX 200' 'NX 300' 'Navara'
#  'Navigator' 'Nemo ����.' 'Neon' 'New Beetle' 'Nexia' 'Nitro' 'Niva' 'Note'
#  'Nubira' 'Octavia' 'Octavia A5' 'Octavia A7' 'Octavia Scout'
#  'Octavia Tour' 'Omega' 'One' 'Opirus' 'Optima' 'Orion' 'Outback'
#  'Outlander' 'Outlander XL' 'PT Cruiser' 'Paceman' 'Pacifica' 'Pajero'
#  'Pajero Pinin' 'Pajero Sport' 'Pajero Wagon' 'Panamera' 'Panda'
#  'Partner ����.' 'Passat B2' 'Passat B3' 'Passat B4' 'Passat B5'
#  'Passat B6' 'Passat B7' 'Passat B8' 'Passat CC' 'Pathfinder' 'Patriot'
#  'Patrol' 'Phaeton' 'Phantom' 'Phedra' 'Picanto' 'Pilot' 'Pointer'
#  'Polarsun Business Van' 'Polo' 'Pony' 'Prelude' 'Premacy' 'Previa'
#  'Primastar ����.' 'Primera' 'Prisma' 'Prius' 'Pro Ceed' 'Probe' 'Punto'
#  'Q3' 'Q5' 'Q50' 'Q7' 'Q70' 'QQ' 'QX50' 'QX70' 'QX80' 'Qashqai' 'Qashqai+2'
#  'Qubo ����.' 'R 320' 'R8' 'RAM' 'RCZ' 'RL' 'RX 200' 'RX 270' 'RX 300'
#  'RX 330' 'RX 350' 'RX 400' 'RX 450' 'RX-8' 'Ram Van' 'Range Rover'
#  'Range Rover Evoque' 'Range Rover Sport' 'Ranger' 'Rapid' 'Rapide' 'Rav 4'
#  'Rekord' 'Rexton' 'Rexton II' 'Rexton W' 'Rio' 'Roadster' 'Rodius'
#  'Roomster' 'S 140' 'S 250' 'S 280' 'S 300' 'S 320' 'S 350' 'S 400' 'S 420'
#  'S 430' 'S 500' 'S 55' 'S 550' 'S 600' 'S 63 AMG' 'S 65 AMG' 'S-Guard'
#  'S-Type' 'S2000' 'S4' 'S40' 'S5' 'S6' 'S60' 'S8' 'S80' 'SC 430'
#  'SL 500 (550)' 'SL 55 AMG' 'SLK 200' 'SLK 350' 'SM5' 'SRX' 'SX4' 'Safari'
#  'Safe' 'Saibao' 'Samurai' 'Sandero' 'Sandero StepWay' 'Santa FE' 'Savana'
#  'Scenic' 'Scion' 'Scirocco' 'Scorpio' 'Scudo ����.' 'Sebring' 'Sens'
#  'Sentra' 'Sephia' 'Sequoia' 'Sharan' 'Shuma' 'Shuttle' 'Sienna' 'Sierra'
#  'Smart' 'Solaris' 'Solenza' 'Sonata' 'Sorento' 'Soul' 'Space Star'
#  'Space Wagon' 'Spaceback' 'Splash' 'Sportage' 'Sprinter 208 ����.'
#  'Sprinter 210 ����.' 'Sprinter 211 ����.' 'Sprinter 212 ����.'
#  'Sprinter 213 ����.' 'Sprinter 310 ����.' 'Sprinter 311 ����.'
#  'Sprinter 312 ����.' 'Sprinter 313 ����.' 'Sprinter 315 ����.'
#  'Sprinter 316 ����.' 'Sprinter 318 ����.' 'Sprinter 319 ����.'
#  'Sprinter 324 ����.' 'Sprinter ����.' 'Stanza' 'Stilo' 'Stratus' 'Sunny'
#  'SuperNova' 'Superb' 'Swift' 'Symbol' 'Syncro' 'T2 (Transporter)'
#  'T3 (Transporter)' 'T4 (Transporter) ����' 'T4 (Transporter) ����.'
#  'T5 (Transporter) ����' 'T5 (Transporter) ����.' 'T6 (Transporter) ����'
#  'T6 (Transporter) ����.' 'TIIDA' 'TL' 'TLX' 'TT' 'Tacoma' 'Tacuma'
#  'Taurus' 'Teana' 'Tempra' 'Terios' 'Terracan' 'Terrano' 'Thema'
#  'Thunderbird' 'Tiggo' 'Tigra' 'Tiguan' 'Tipo' 'Toledo' 'Touareg' 'Touran'
#  'Tourneo Connect ����.' 'Tourneo Courier' 'Town Car' 'Trafic ����.'
#  'Transit Connect ����.' 'Transit Custom' 'Transit ����.' 'Tribeca'
#  'Tribute' 'Trooper' 'Tucson' 'Tundra' 'Uno' 'Up' 'V 250' 'V40' 'V5'
#  'Vaneo' 'Vanette ����.' 'Vectra A' 'Vectra B' 'Vectra C' 'Vento' 'Venza'
#  'Viano ����.' 'Vida' 'Virage' 'Vista' 'Vitara' 'Vito ����.' 'Vivaro ����.'
#  'Volt' 'Voyager' 'Wrangler' 'X-Trail' 'X-Type' 'X1' 'X3' 'X5' 'X5 M' 'X6'
#  'X6 M' 'XC60' 'XC70' 'XC90' 'XE' 'XF' 'XJR-S' 'XKR' 'XV' 'Xantia'
#  'Xedos 6' 'Xedos 9' 'Xenon' 'Xsara' 'Xsara Picasso' 'Yaris' 'Yeti' 'Z3'
#  'Z4' 'ZDX' 'Zafira' 'i10' 'i20' 'i30' 'ix55 (Veracruz)' '������'
#  '������-����' '�������' '������������']
#
# _____________________________________________________________________
#
# Column: drive
# Unique Values: 3
#
# ['front' 'full' 'rear']

# %% [markdown]
# ## Heatmap using Matplotlob

# %%
gp_body_eng = car_ads.groupby(['body','engType'])['body','engType'].count()
gp_body_eng.columns = ['bodycount', 'engTypecount']

# %%
print(gp_body_eng.head(10))
#gp_body_eng=pd.Series.to_frame(gp_body_eng)
#print(gp_body_eng.index)
gp_body_eng.columns

#This dataframe is Multi-index
print(gp_body_eng.index.names)
#print(gp_body_eng.index)
#gp_body_eng.head[]
#table = gp_body_eng.pivot(index='engType', columns='body', values='price')
print(gp_body_eng.sort_index)
# Out:
#                    bodycount  engTypecount
# body      engType
# crossover Diesel         766           766
#           Gas            421           421
#           Other           52            52
#           Petrol         830           830
# hatch     Diesel         129           129
#           Gas            200           200
#           Other          124           124
#           Petrol         799           799
# other     Diesel         296           296
#           Gas             84            84
# ['body', 'engType']
# <bound method DataFrame.sort_index of                    bodycount  engTypecount
# body      engType
# crossover Diesel         766           766
#           Gas            421           421
#           Other           52            52
#           Petrol         830           830
# hatch     Diesel         129           129
#           Gas            200           200
#           Other          124           124
#           Petrol         799           799
# other     Diesel         296           296
#           Gas             84            84
#           Other           55            55
#           Petrol         403           403
# sedan     Diesel         535           535
#           Gas            865           865
#           Other          177           177
#           Petrol        2069          2069
# vagon     Diesel         390           390
#           Gas             96            96
#           Other           27            27
#           Petrol         209           209
# van       Diesel         897           897
#           Gas             56            56
#           Other           27            27
#           Petrol          69            69>

# %%
gp_body_eng.loc['crossover':'van']
# Out:
#                    body  engType
# body      engType
# crossover Diesel    766      766
#           Gas       421      421
#           Other      52       52
#           Petrol    830      830
# hatch     Diesel    129      129
#           Gas       200      200
#           Other     124      124
#           Petrol    799      799
# other     Diesel    296      296
#           Gas        84       84
#           Other      55       55
#           Petrol    403      403
# sedan     Diesel    535      535
#           Gas       865      865
#           Other     177      177
#           Petrol   2069     2069
# vagon     Diesel    390      390
#           Gas        96       96
#           Other      27       27
#           Petrol    209      209
# van       Diesel    897      897
#           Gas        56       56
#           Other      27       27
#           Petrol     69       69

# %%
gp_body_eng.head(3)
# Out:
#                    body  engType
# body      engType
# crossover Diesel    766      766
#           Gas       421      421
#           Other      52       52

# %%
car_ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
# car             9576 non-null category
# price           9576 non-null float64
# body            9576 non-null category
# mileage         9576 non-null int64
# engV            9142 non-null float64
# engType         9576 non-null category
# registration    9576 non-null category
# year            9576 non-null int64
# model           9576 non-null category
# drive           9065 non-null category
# dtypes: category(6), float64(2), int64(2)
# memory usage: 372.3 KB

# %%
car_ads.drive.cat.categories
# Out:
# Index(['front', 'full', 'rear'], dtype='object')

# %%
#Drop missing observations
car_ads_no_missing = car_ads.dropna()

# %%
car_ads_no_missing.head(5)
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 5         Nissan  16600.0  crossover       83   2.0  Petrol          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 5  2013  X-Trail   full

# %%
#Distribution Plot 
vis1 = sns.distplot(car_ads_no_missing.year, bins=40, kde=False)

# %%
plt.hist([car_ads_no_missing[car_ads_no_missing.body == 'crossover'].year,
                     car_ads_no_missing[car_ads_no_missing.body == 'sedan'].year], 
                    stacked=True,
                    bins=30
        )
plt.show()

# %%
list1 = list()
for carbody in car_ads_no_missing.body.cat.categories:
    list1.append(car_ads_no_missing[car_ads_no_missing.body == carbody].year)

mylabels = list()
for carbody in car_ads_no_missing.body.cat.categories:
    mylabels.append(carbody)
    
plt.hist(list1,
         stacked=True,
         bins=20,
        rwidth=1,
        label=mylabels
        )
plt.legend()
plt.show()

# %%
# Linear Model Plot
vis3 = sns.lmplot(data=car_ads_no_missing[car_ads_no_missing['price']<500000], 
                  x="price",
                  y="mileage",
                  fit_reg=False,
                  hue = 'body',
                  size=6,
                  scatter_kws={"alpha":0.6, "s":40}
       )

# %%
#marker size
vis3 = sns.lmplot(data=car_ads_no_missing[car_ads_no_missing['price']<500000].head(300), 
                  x="price",
                  y="mileage",
                  fit_reg=False,
                  hue = 'body',
                  size=6
          
         )

# %%
#Boxplots
vis2 = sns.boxplot(
    data=car_ads_no_missing[car_ads_no_missing['price']<70000], 
    x="body", 
    y = "price"
)

# %%
#jointplots

j = sns.jointplot(data = car_ads_no_missing[
    (car_ads_no_missing.price<10000) &
    (car_ads_no_missing.mileage<500) &
    (car_ads_no_missing.mileage>5)
    ], 
     kind='hex',
     #size=20,
     x='price' , 
     y='mileage')


#Jointplots gives more meaning, 
#if they are plotted between two variables which 
#have similar units
#like Audience rating vs Critic rating

# %% [markdown]
# ## Linear Model Plot in Seaborn
# sns.lmplot('x', 'y', data=df, fit_reg=False)

# %%
data_subset = car_ads_no_missing[(car_ads_no_missing.mileage<550)
                                & (car_ads_no_missing.price<50000)]
sns.set_context("talk")
sns.lmplot(y='mileage', x='price', data = data_subset, fit_reg=False, hue='engType', 
           scatter_kws={"alpha":0.6, "s":40})
plt.show()

# %%
k1 = sns.kdeplot(
            data_subset.mileage, 
            data_subset.price,
           
            #shade_lowest=False,
            shade=True,
            cmap='Reds'
)


k1b = sns.kdeplot(
            data_subset.mileage, 
            data_subset.price,
           
            #shade_lowest=False,
            #shade=True,
            cmap='Reds'
)

#tip = overlappinng to make it look smoother
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d802eb4f8083> in <module>()
#       1
#       2 k1 = sns.kdeplot(
# ----> 3             data_subset.mileage,
#       4             data_subset.price,
#       5
#
# NameError: name 'data_subset' is not defined

# %%
#Working with Subplots

# %%
f, axes = plt.subplots(1,2, figsize=(12,6), sharex=True)

f1 = sns.kdeplot(
            data_subset.mileage, 
            data_subset.price,
           
            #shade_lowest=False,
            #shade=True,
            cmap='Reds',
            ax = axes[0]
)
f1.set(xlim=(0,400))

f2 = sns.kdeplot(
            data_subset.mileage, 
            data_subset.price,
           
            #shade_lowest=False,
            shade=True,
            cmap='Reds',
            ax = axes[1]
)
f2.set_title("Red shaded Price")
sns.plt.suptitle('KDE Plots')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-dbc82368d16e> in <module>()
#       2
#       3 f1 = sns.kdeplot(
# ----> 4             data_subset.mileage,
#       5             data_subset.price,
#       6
#
# NameError: name 'data_subset' is not defined

# %%
w = sns.boxplot(
            x=data_subset.engType, 
            y=data_subset.mileage
)

# %%
f, axs = plt.subplots(1,2, figsize=(16,6))


f1 = sns.violinplot(
            y=data_subset.mileage, 
            x=data_subset.engType, ax=axs[0]
)
f2 = sns.boxplot(
            y=data_subset.mileage, 
            x=data_subset.engType, ax=axs[1]
)
# Out:
#   File "<ipython-input-137-c89dc299fe7f>", line 2
#     for ax in g.axs.flat
#                         ^
# SyntaxError: invalid syntax

# %%
car_ads_no_missing.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
#Creating a facet Grid
# Creating coordinates and diagonals
g = sns.FacetGrid(car_ads_no_missing[
    (car_ads_no_missing.price<10000) & (car_ads_no_missing.price>500)], 
                  col='engType', 
                  row ='drive', 
                  hue='engType')
kws = dict(s=50, linewidth=0.5, edgecolor='black', alpha=0.3)

for ax in g.axes.flat:
       ax.plot((0, 1000), (0, 10000), ls="--", c="lightgray")
g.add_legend()                
g = g.map(plt.scatter, 
          'mileage','price',  **kws)

# %%
#With Different plots using col="Name" or rows="Name"
sns.lmplot(x='year', y='price', data = car_ads_no_missing, col='body', row='engType', fit_reg=False)
plt.show()

# %%
#With Different plots using hue="columnName"
sns.lmplot(x='year', y='price', data = car_ads_no_missing, hue='body', fit_reg=False)
plt.show()

# %%
sns.residplot(x='mileage', y='price', data = car_ads_no_missing)
plt.show()

# %%
#With Different plots using hue="columnName"
#g = sns.regplot(x='year', y='price', data = car_ads_no_missing, color='red')

g = sns.regplot(x='year', y='price', data = car_ads_no_missing,   color='green', scatter_kws={"alpha":0.3})
g.set(xlim=(1970,2010), ylim=(0,60000))



sns.despine()

plt.show()

# %%
### STyling Dashboards
car_ads_no_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8739 entries, 0 to 9575
# Data columns (total 10 columns):
# car             8739 non-null category
# price           8739 non-null float64
# body            8739 non-null category
# mileage         8739 non-null int64
# engV            8739 non-null float64
# engType         8739 non-null category
# registration    8739 non-null category
# year            8739 non-null int64
# model           8739 non-null category
# drive           8739 non-null category
# dtypes: category(6), float64(2), int64(2)
# memory usage: 408.6 KB

# %%
fn, axes = plt.subplots(2,3, figsize=(15,8))
p1 = sns.distplot(car_ads_no_missing[car_ads_no_missing.price<60000].price,  ax=axes[0,0])
p1.set_title("\n\n\n\nPrice Distribution")
p1.set_xlim(0)
p2 = sns.distplot(car_ads_no_missing[car_ads_no_missing.price<60000].mileage, ax=axes[0,1])
p2.set_title("\n\n\n\nMileage Distribution")

p3 = sns.kdeplot(car_ads_no_missing.price,  
                 car_ads_no_missing.mileage,                    
                 ax=axes[0,2],
                shade=True,
                 cmap='rainbow'
                )

p3 = sns.kdeplot(car_ads_no_missing.price,  
                 car_ads_no_missing.mileage,                    
                 ax=axes[0,2],
                shade=False,
                 cmap='Pastel1'
                )
p3.set_title("\n\n\n\nPrice vs Mileage")
p3.set_xlim(0,30000)
p3.set_ylim(0,420)



p5 = sns.distplot(car_ads_no_missing[(car_ads_no_missing.price<60000) & (car_ads_no_missing.year>1940)].year, bins=20, ax=axes[1,0])
p5.set_title("\n\n\n\nYear")
p6 = sns.distplot(car_ads_no_missing[(car_ads_no_missing.price<60000) & (car_ads_no_missing.engV<12)].engV, bins=20, ax=axes[1,1])
p6.set_title("\n\n\n\nEngV Distribution")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     303                 pass
#     304             else:
# --> 305                 return printer(obj)
#     306             # Finally look for special method names
#     307             method = get_real_method(obj, self.print_method)
#
# /opt/conda/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     237
#     238     if 'png' in formats:
# --> 239         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     240     if 'retina' in formats or 'png2x' in formats:
#     241         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/conda/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     121
#     122     bytes_io = BytesIO()
# --> 123     fig.canvas.print_figure(bytes_io, **kw)
#     124     data = bytes_io.getvalue()
#     125     if fmt == 'svg':
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2198                     orientation=orientation,
#    2199                     dryrun=True,
# -> 2200                     **kwargs)
#    2201                 renderer = self.figure._cachedRenderer
#    2202                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     800                     textrenderer.draw_text(gc, x, y, clean_line,
#     801                                            textobj._fontproperties, angle,
# --> 802                                            ismath=ismath, mtext=mtext)
#     803
#     804         gc.restore()
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     603         """
#     604
# --> 605         self._draw_text_as_path(gc, x, y, s, prop, angle, ismath)
#     606
#     607     def _get_text_path_transform(self, x, y, s, prop, angle, ismath):
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/patheffects.py in _draw_text_as_path(self, gc, x, y, s, prop, angle, ismath)
#     153         # Implements the naive text drawing as is found in RendererBase.
#     154         path, transform = self._get_text_path_transform(x, y, s, prop,
# --> 155                                                         angle, ismath)
#     156         color = gc.get_rgb()
#     157         gc.set_linewidth(0.0)
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/backend_bases.py in _get_text_path_transform(self, x, y, s, prop, angle, ismath)
#     632                                                    usetex=False)
#     633
# --> 634         path = Path(verts, codes)
#     635         angle = angle / 180. * 3.141592
#     636         if self.flipy():
#
# /opt/conda/lib/python3.5/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     139         if (vertices.ndim != 2) or (vertices.shape[1] != 2):
#     140             msg = "'vertices' must be a 2D list or array with shape Nx2"
# --> 141             raise ValueError(msg)
#     142
#     143         if codes is not None:
#
# ValueError: 'vertices' must be a 2D list or array with shape Nx2

# %%
car_ads_no_missing.head()
car_subset = car_ads_no_missing[['price','engType','body']]
car_subset.head()
# Out:
#      price engType       body
# 0  15500.0     Gas  crossover
# 1  20500.0     Gas      sedan
# 2  35000.0  Petrol      other
# 3  17800.0  Diesel        van
# 5  16600.0  Petrol  crossover

# %%
##Another way
car_subset1 = car_ads_no_missing.ix[:,['price','engType','body']]
car_subset1.head()
# Out:
#      price engType       body
# 0  15500.0     Gas  crossover
# 1  20500.0     Gas      sedan
# 2  35000.0  Petrol      other
# 3  17800.0  Diesel        van
# 5  16600.0  Petrol  crossover

# %% [markdown]
# ## Heatmap using Matplotlib

# %%
car_gp = car_subset.groupby(by=['body','engType']).median()
car_gp
# Out:
#                      price
# body      engType
# crossover Diesel   26400.0
#           Gas      15900.0
#           Other    17500.0
#           Petrol   19000.0
# hatch     Diesel    9000.0
#           Gas       4950.0
#           Other     9250.0
#           Petrol    6994.5
# other     Diesel   10299.0
#           Gas       6200.0
#           Other    10200.0
#           Petrol   12600.0
# sedan     Diesel    8999.5
#           Gas       6400.0
#           Other     7950.0
#           Petrol    8500.0
# vagon     Diesel    7850.0
#           Gas       6500.0
#           Other     6500.0
#           Petrol    7000.0
# van       Diesel    8275.0
#           Gas       5999.0
#           Other     7600.0
#           Petrol    6500.0

# %%
car_gp_rs = car_gp.reset_index()
car_gp_rs.head(5)
# Out:
#         body engType    price
# 0  crossover  Diesel  26400.0
# 1  crossover     Gas  15900.0
# 2  crossover   Other  17500.0
# 3  crossover  Petrol  19000.0
# 4      hatch  Diesel   9000.0

# %%
car_pivot = car_gp_rs.pivot(index='body',columns='engType',values='price')
car_pivot
# Out:
# engType     Diesel      Gas    Other   Petrol
# body
# crossover  26400.0  15900.0  17500.0  19000.0
# hatch       9000.0   4950.0   9250.0   6994.5
# other      10299.0   6200.0  10200.0  12600.0
# sedan       8999.5   6400.0   7950.0   8500.0
# vagon       7850.0   6500.0   6500.0   7000.0
# van         8275.0   5999.0   7600.0   6500.0

# %%
fig = plt.figure(figsize=(8, 5), dpi=100)
s = sns.heatmap(car_pivot)
s.set_title("Heatmap for Body and EngineType Median Price")
plt.show()
