# %%
#!pip install faker
#!pip uninstall elasticsearch --yes
#!pip uninstall certifi --yes
#!pip install ujson
#!pip install -U elasticsearch
#!pip install -U certifi
#!pip install pandasticsearch[pandas]
#!pip install elasticsearch_dsl

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import requests
from faker import Faker
import ujson as json
import pandas as pd
import requests
from numpy import random 
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from elasticsearch_dsl import Search, DocType, Date, Integer, Keyword, Text
from datetime import datetime
from elasticsearch_dsl.connections import connections
import requests
from random import randint
from pandas.io.json import json_normalize
from pandasticsearch import DataFrame
from pandasticsearch import Select
eda_new
ES_HOST = 'http://ec2-34-205-15-150.compute-1.amazonaws.com:9200'
INDEX = "eda_small"
DOC_TYPE="user"
es = Elasticsearch(ES_HOST)
es.indices.put_settings(index=INDEX,
                        body= {"index" : {
                                "max_result_window" : 750000
                              }})

# %%
## Create Elasticsearch Query
query0 = {
            "from" : 0, 
            "size" : 70000,
            "query": {
                        "match_all": {}
                     }
            }

# %%
## Import Data into a Panda dataframe
result_dict = es.search(index=INDEX, body=query0)
df = Select.from_dict(result_dict).to_pandas()
df.info()

# %%
df.drop(['_index', '_score', '_type'],inplace=True,axis=1,errors='ignore')

# %%
df.head()
# Out:
#                                       Avg Order Value       City  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b      1128.568182    Lucknow
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0      3375.538462    Chennai
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d       674.220000      Noida
# c1e9d162-7349-ee0f-556d-264aca508b47      3249.153846  Ahmedabad
# 18a3b227-a9e6-412d-25c9-771966d9cd02      1089.304348    Chennai
#
#                                       days_since_last_purchase  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b                        52
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0                        29
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d                        24
# c1e9d162-7349-ee0f-556d-264aca508b47                        45
# 18a3b227-a9e6-412d-25c9-771966d9cd02                         1
#
#                                       discount_percentage email_unsubscribe  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b                   29             False
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0                   23             False
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d                   20             False
# c1e9d162-7349-ee0f-556d-264aca508b47                   10             False
# 18a3b227-a9e6-412d-25c9-771966d9cd02                   23             False
#
#                                       f_score         lifecycle  m_score  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b        8  Loyal (Sleeping)        8
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0        5  Loyal (Sleeping)        8
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d        8  Loyal (Sleeping)        8
# c1e9d162-7349-ee0f-556d-264aca508b47        5  Loyal (Sleeping)        8
# 18a3b227-a9e6-412d-25c9-771966d9cd02        6    Loyal (Active)        8
#
#                                                  name  num_of_orders  r_score  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b  Michael Goodman             44        5
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0       Tony Adams             13        7
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d       Eric Clark             50        7
# c1e9d162-7349-ee0f-556d-264aca508b47    Daniel Thomas             13        5
# 18a3b227-a9e6-412d-25c9-771966d9cd02    Samuel Miller             23        9
#
#                                       revenue  rfm_score  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b    49657         21
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0    43882         20
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d    33711         23
# c1e9d162-7349-ee0f-556d-264aca508b47    42239         18
# 18a3b227-a9e6-412d-25c9-771966d9cd02    25054         23
#
#                                                     segments  \
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b  [High Discount Seeker]
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0       [High Cart Value]
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d                   [NCR]
# c1e9d162-7349-ee0f-556d-264aca508b47       [High Cart Value]
# 18a3b227-a9e6-412d-25c9-771966d9cd02                      []
#
#                                       total_discount_revenue
# _id
# 0ce81a1e-f3c2-02d4-8fd1-49307ad26c1b                14400.53
# 4d88c2e9-fb30-2fda-4b23-807b08457cf0                10092.86
# fad0c0a5-8ec6-721e-8180-d902cf1fa86d                 6742.20
# c1e9d162-7349-ee0f-556d-264aca508b47                 4223.90
# 18a3b227-a9e6-412d-25c9-771966d9cd02                 5762.42

# %% [markdown]
# ## 1.1 Histograms
# - A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of **continuous data**.
# - This allows the inspection of the data for its underlying distribution (e.g., normal distribution),width of spread, median data value, outliers, skewness, etc.

# %%
fig, axes = plt.subplots(1,3, figsize=(15,6))

sns.distplot(df.num_of_orders[df.num_of_orders>0],  kde=False, ax = axes[0], hist_kws={"linewidth": 1, "alpha": 0.8, "edgecolor":"grey"})
axes[0].set_title("Total Order Distribution")
axes[0].set(xlabel='Number of Orders', ylabel='Count of Users')


sns.distplot(df['Avg Order Value'][df['Avg Order Value']>0] ,kde=False, ax = axes[1],hist_kws={"linewidth": 1,"alpha": 0.8, "edgecolor":"grey"})
axes[1].set(xlabel="Avg Order Value", ylabel='Count of Users')
axes[1].set_title("Avg Order Value Distribution")



sns.distplot(df.revenue[df.revenue>0] , kde=False, ax = axes[2],hist_kws={"linewidth": 1,"alpha": 0.8, "edgecolor":"grey"})
axes[2].set(xlabel="Total Revenue", ylabel='Count of Users')
axes[2].set_title("Total Revenue Distribution")




sns.plt.suptitle('HISTOGRAMS',fontsize=18)
plt.show()

# %% [markdown]
# ## 1.2 Beeswarm Plot
# A Beeswarm plot is a two-dimensional visualisation technique where data points are plotted relative to a fixed reference axis so that no two datapoints overlap.
#
# #### Why it is used?
# Imagine that you have a continuous data variable (like Customer Revenue) that you want to compare between two or more different treatment groups (like Lifecycle of Customers). The potential problems with other plots is that you could have very dense grouping of data points, leading to data points being plotted over top of one another on the chart and obscuring the data.
#
# Swarm plot move data points with the minimum distance away from one another to avoid overlays. The result is a plot where you can see each distinct data point,

# %%
## Generating a swarm plot
#sns.swarmplot(x=df.lifecycle, y=df.avg_revenue_per_month ,hue=df.email_unsubscribe)
#_ = plt.title("SWARM PLOT \n\nRevenue distribution with Lifecycle", fontsize=16)
#_ = plt.xlabel("Lifecyle")
#_ = plt.ylabel("Avg. Revenue per month ")
#_ = plt.legend(title= 'Email Subscribed', bbox_to_anchor=(1,1),ncol=1)
# bbox is bounding box with lower left corner at position 
#plt.show()


fig, axes = plt.subplots(1,2, figsize=(15,6))

sns.swarmplot(x=df.lifecycle, y=df['Avg Order Value'] ,ax = axes[0], hue=df.email_unsubscribe)
axes[0].set_title("Revenue Distribution")
axes[0].set(xlabel='Lifecycle', ylabel='Count of Users')
axes[0].legend_.remove()

sns.swarmplot(x=df.lifecycle, y=df.revenue ,ax = axes[1],hue=df.email_unsubscribe)
axes[1].set(xlabel="Lifecyle", ylabel='Avg. Revenue per month')
axes[1].set_title("Avg. Revenue Distrubution")

sns.plt.suptitle('SWARM PLOT ',fontsize=18)
_ = plt.legend(title= 'Email Subscribed', bbox_to_anchor=(1,1),ncol=1)
# bbox is bounding box with lower left corner at position 
plt.show()

# %% [markdown]
# ### Interpretation from above Swarmplots
# - Which lifecyle has more total revenue
# - Which lifecycle has lower avg. revenue per month
