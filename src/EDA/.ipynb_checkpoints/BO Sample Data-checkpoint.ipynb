# %%
#!pip install faker
#!pip uninstall elasticsearch --yes
#!pip uninstall certifi --yes
#!pip install ujson
#!pip install -U elasticsearch
#!pip install -U certifi
#!pip install pandasticsearch[pandas]
#!pip install elasticsearch_dsl

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import requests
from faker import Faker
import ujson as json
import pandas as pd
import requests
from numpy import random 
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from elasticsearch_dsl import Search, DocType, Date, Integer, Keyword, Text
from datetime import datetime
from elasticsearch_dsl.connections import connections
import requests
from random import randint
from pandas.io.json import json_normalize
from pandasticsearch import DataFrame
from pandasticsearch import Select

ES_HOST = 'http://ec2-34-205-15-150.compute-1.amazonaws.com:9200'
INDEX = "eda1"
DOC_TYPE="user"
es = Elasticsearch(ES_HOST)

# %%
## Create Elasticsearch Query
query = {
            "from" : 0, 
            "size" : 3000,
            "query": {
                        "match_all": {}
                     }
            }

# %%
## Import Data into a Panda dataframe
result_dict = es.search(index=INDEX, body=query)
df = Select.from_dict(result_dict).to_pandas()
df = df.set_index(['email'])
df.drop(['_index', '_score', '_type', '_id'],inplace=True,axis=1,errors='ignore')
df.head()
# Out:
#                                                                         address  \
# email
# brianwhite@example.org         9035 May Lakes Apt. 180\nWest Margaret, OK 77492
# podonnell@example.org          22532 Ian Locks\nPort Danachester, HI 18982-5173
# jmata@example.net             0082 Kevin Village Suite 285\nLucasport, NY 34...
# kimberlytaylor@example.org    18693 Christopher Street\nJosephtown, OR 03025...
# elizabethsalazar@example.net        3076 Zavala Trail\nSummerton, MN 23783-0783
#
#                               avg_revenue_per_month                   country  \
# email
# brianwhite@example.org                  2939.000000  Turks and Caicos Islands
# podonnell@example.org                    760.272727                      Cuba
# jmata@example.net                        471.857143                  Cambodia
# kimberlytaylor@example.org               250.000000                   Liberia
# elizabethsalazar@example.net             849.300000                   Namibia
#
#                               discount_percentage email_unsubscribe  f_score  \
# email
# brianwhite@example.org                         28             False        5
# podonnell@example.org                          17              True        0
# jmata@example.net                              26              True        5
# kimberlytaylor@example.org                     18              True        5
# elizabethsalazar@example.net                   18             False        4
#
#                                 fav_color                         job  \
# email
# brianwhite@example.org         DodgerBlue    Advertising art director
# podonnell@example.org         YellowGreen  Regulatory affairs officer
# jmata@example.net             DarkMagenta                        Land
# kimberlytaylor@example.org         Salmon                Youth worker
# elizabethsalazar@example.net  ForestGreen                Youth worker
#
#                               lifecycle  m_score             name  \
# email
# brianwhite@example.org                8        6  Bryan Rodriguez
# podonnell@example.org                 2        8   Joshua Alvarez
# jmata@example.net                     3        5   Matthew Deleon
# kimberlytaylor@example.org            9        9     Megan Larson
# elizabethsalazar@example.net          4        5    Nancy Raymond
#
#                               num_of_orders  r_score  revenue  rfm_score  \
# email
# brianwhite@example.org                    0        9      557         20
# podonnell@example.org                     3        5     2776         13
# jmata@example.net                         2        0     1407         10
# kimberlytaylor@example.org                0        3      116         17
# elizabethsalazar@example.net              0        5      181         14
#
#                                       signup_date  total_discount_revenue
# email
# brianwhite@example.org        2017-03-13T15:34:19                  155.96
# podonnell@example.org         2017-05-06T02:21:35                  471.92
# jmata@example.net             2017-05-16T14:03:47                  365.82
# kimberlytaylor@example.org    2017-05-01T20:54:28                   20.88
# elizabethsalazar@example.net  2017-04-23T12:43:28                   32.58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, brianwhite@example.org to fkelly@example.org
# Data columns (total 17 columns):
# address                   3000 non-null object
# avg_revenue_per_month     3000 non-null float64
# country                   3000 non-null object
# discount_percentage       3000 non-null int64
# email_unsubscribe         3000 non-null bool
# f_score                   3000 non-null int64
# fav_color                 3000 non-null object
# job                       3000 non-null object
# lifecycle                 3000 non-null int64
# m_score                   3000 non-null int64
# name                      3000 non-null object
# num_of_orders             3000 non-null int64
# r_score                   3000 non-null int64
# revenue                   3000 non-null int64
# rfm_score                 3000 non-null int64
# signup_date               3000 non-null object
# total_discount_revenue    3000 non-null float64
# dtypes: bool(1), float64(2), int64(8), object(6)
# memory usage: 401.4+ KB

# %% [markdown]
# ## 1.1 Beeswarm Plot
# A Beeswarm plot is a two-dimensional visualisation technique where data points are plotted relative to a fixed reference axis so that no two datapoints overlap.
#
# #### Why it is used?
# Imagine that you have a continuous data variable (like Customer Revenue) that you want to compare between two or more different treatment groups (like Lifecycle of Customers). The potential problems with other plots is that you could have very dense grouping of data points, leading to data points being plotted over top of one another on the chart and obscuring the data.
#
# Swarm plot move data points with the minimum distance away from one another to avoid overlays. The result is a plot where you can see each distinct data point,

# %%
## Generating a swarm plot
sns.swarmplot(x=df.lifecycle, y=df.revenue ,hue=df.email_unsubscribe)
_ = plt.title("SWARM PLOT \n ------------------- \nRevenue distribution with Lifecycle", fontsize=16)
_ = plt.xlabel("Lifecyle")
_ = plt.ylabel("Revenue")
_ = plt.legend(title= 'Email Subscribed', bbox_to_anchor=(1,1),ncol=1)
# bbox is bounding box with lower left corner at position 
plt.show()
